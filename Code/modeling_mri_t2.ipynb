# %%
# Gneral Imports

import os
import pickle
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import torch 
from pathlib import Path
import torchvision
from torchvision.datasets import MNIST
import torchvision.transforms as transforms
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
directory = Path("/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All" )

# There are 184752 images from AV45(162120) and FDG (22632) in total

# AV45 0.0 120120: 0.5 31500 1.0 6720: 2.0 3360: 3.0 420
# FDG 0.0 120120: 0.5 31500 1.0 6720: 2.0 3360: 3.0 420


def perc(x, tot):
    return (x/tot)*100


MRI_T2_00 = (len(list(directory.glob("MRI_T2/0.0/*.png"))))
MRI_T2_05 = (len(list(directory.glob("MRI_T2/0.5/*.png"))))
MRI_T2_total = (len(list(directory.glob("MRI_T2/*/*.png"))))



print(f"Image count for MRI_T2 0.0: {MRI_T2_00} Percentage: {perc(MRI_T2_00, MRI_T2_total)}")
print(f"Image count for MRI_T2 0.5: {MRI_T2_05} Percentage: {perc(MRI_T2_05, MRI_T2_total)}")
# Out:
# Image count for MRI_T2 0.0: 36989 Percentage: 62.29201751431458
# Image count for MRI_T2 0.5: 12781 Percentage: 21.524082182553048
# /Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/MRI_T2/0.5/OAS30157_d2674_0.5_150.png

# %%
modeling_mri_t2_folder = "/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/modeling_mri_t2/"
if os.path.exists(modeling_mri_t2_folder):
    print("folder existed")
else:
    os.makedirs(modeling_mri_t2_folder)

base_directory = modeling_mri_t2_folder


# Create the classes folder tiltled Demented and Not Demented


try:
    os.replace("/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/modeling_mri_t2/0.5", "/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/modeling_mri_t2/demented")
except Exception as err:
    print(err)
    print("it was previously moved")


temp = (list(directory.glob("MRI_T2/0.0/*.png")))

not_demented_folder = modeling_mri_t2_folder + "/not_demented"
if os.path.exists(not_demented_folder):
    print("folder existed")
else:
    os.makedirs(not_demented_folder)

# for i in range(12782):
#     full_path = temp[i]
#     file_name = str(temp[i]).split("/")[9]
#     # print(file_name)
#     os.replace(full_path, not_demented_folder + f"/{file_name}")
# Out:
# folder existed
# [Errno 2] No such file or directory: '/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/modeling_mri_t2/0.5' -> '/Users/SeanKelly1/Documents/FinalThesis(2023Ulster)/Raw/All/modeling_mri_t2/demented'
# it was previously moved
# folder existed
# OAS30636_TSE_0.0_20.png
# OAS30737_d1137_0.0_136.png
# OAS30492_TSE_0.0_27.png
# OAS30235_d1175_0.0_152.png
# OAS30487_TSE_0.0_27.png
# OAS30623_TSE_0.0_20.png
# OAS31114_d3479_0.0_147.png
# OAS31137_d3443_0.0_144.png
# OAS30476_TSE_0.0_21.png
# OAS30516_d1800_0.0_163.png
# OAS30788_d0201_0.0_151.png
# OAS30406_TSE_0.0_19.png
# OAS30562_d0030_0.0_152.png
# OAS30602_d2442_0.0_158.png
# OAS30413_TSE_0.0_19.png
# OAS30900_d0051_0.0_164.png
# OAS30079_d0019_0.0_139.png
# OAS30247_TSE_0.0_24.png
# OAS30455_d5422_0.0_161.png
# OAS30339_d0066_0.0_136.png
# OAS30659_d0410_0.0_135.png
# OAS30817_d2324_0.0_145.png
# OAS30674_d1011_0.0_161.png
# OAS30062_d1745_0.0_151.png
# OAS30253_1_0.0_13.png
# OAS31012_TSE_0.0_23.png
# ...
